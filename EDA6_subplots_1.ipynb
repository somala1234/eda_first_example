# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,1)
# Out:
# <Axes: >

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)
plt.subplot(3,3,3)

plt.subplot(3,1,3)
# Out:
# <Axes: >

# %%
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
for i in range(1,3):
    plt.subplot(2,2,i)
