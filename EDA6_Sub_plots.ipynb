# %%
***** SUb plots ****
- If we have multiplpe plots when we apply for loop it is giving one by one 
- It is hard to see all the graphs
-

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
plt.subplot(2,2,2)
plt.subplot(2,2,1)
plt.subplot(1,2,2)
plt.subplot(2,1,2)
# Out:
# <Axes: >

# %%
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
# Read the data again
# Take two columns
 # 1) Continent 2) Case status
# Draw the seaborn individually

# %%
path=os.getcwd() + '\Visadataset.csv'
visa_df = pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
cat_columns = visa_df.select_dtypes(include='object').columns
cat_columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.countplot(x='continent', data=visa_df)
plt.subplot(1,2,2)
sns.countplot(x='continent', data=visa_df)
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.countplot(x='continent', data=visa_df)
plt.title('continent_bar_chart.jpg')

plt.subplot(2,2,2)
sns.countplot(x='has_job_experience', data=visa_df)
plt.title('has_job_experience_bar_chart.jpg')

plt.subplot(2,2,3)
sns.countplot(x='requires_job_training', data=visa_df)
plt.title('requires_job_training_bar_chart.jpg')

plt.subplot(2,2,4)
sns.countplot(x='case_status', data=visa_df)
plt.title('case_status_bar_chart.jpg')
# Out:
# Text(0.5, 1.0, 'case_status_bar_chart.jpg')

# %%
***** Task - 3******
-Take cat columns, slice from index 1, avoid the case id
- So, we have 8 plots, so the grid is 3X3
- For loop length of cat_columns

# %%
plt.figure(figsize=(20,20))
cols=cat_columns[1:]
for i in range(len(cols)):
    plt.subplot(3,3,i+1)
    sns.countplot(x=cols[i], data=visa_df)
    plt.title(f"{cols[i]}_bar_chart")

# %%
***** Whenever the open file read the below things *****

     - import the packages
     - Read the data 
     -

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r'C:\Users\nagal\OneDrive\Documents\NareshIT\EDA\Visadataset.csv'
visa_df = pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
types = visa_df.dtypes
cat_columns = [key for key, value in types.items() if value=='object']
num_columns = [key for key, value in types.items() if value != 'object']
print(cat_columns)
print(num_columns)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# Apply the value counts for categorical columns
### Continent
### Save that value counts in a variable
## new_variable=variable.plot(kind='bar')
## new_variable.bar_label(new_variable.containers[0])
## plt.show()

# %%
cds=visa_df['continent'].value_counts()
ax=cds.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
***** Piechart **********
  - Piechart is as 360 degrees view 
  - It is inder matplotlib package
  - It will take keys and values
  - That will get for vlaue counts

# %%
# Step-1 : get keys from continent value counts
# Step-2 : get values from continent value counts
#Step-3 : plt.pie verify the arguments
#Step-4 : which argument takes values and keys

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
plt.pie(values,
        explode=[0.3,0.3,0.3,0.3,0.3,0.3],
        labels=keys, 
        autopct="%0.2f%%")
plt.show()

# %%
# Netflix 1 Million charge
# WE need to download one dataset 
# We need to perform EDA
# datahack nalaytics vidhya
