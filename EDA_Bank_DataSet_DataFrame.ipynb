# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"C:\Users\nagal\OneDrive\Documents\NareshIT\EDA\bank.csv"
bank_df = pd.read_csv(path, sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
bank_df.tail(10)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4511   46    blue-collar  married  secondary      no      668     yes   no
# 4512   40    blue-collar  married  secondary      no     1100     yes   no
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4514   38    blue-collar  married  secondary      no     1205     yes   no
# 4515   32       services   single  secondary      no      473     yes   no
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
types=dict(bank_df.dtypes)
types
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
job_list = bank_df['job'].unique()
job_list
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
job_count_list=[]
for i in bank_df['job'].unique():
    con=bank_df['job']==i
    count=len(bank_df[con])
    job_count_list.append(count)

job_count_list
# Out:
# [128, 417, 969, 946, 183, 768, 168, 478, 84, 112, 230, 38]

# %%
data = zip(job_list, job_count_list)
cols=['Job', 'Count']
job_data_df = pd.DataFrame(data, columns=cols)
job_data_df
# Out:
#               Job  Count
# 0      unemployed    128
# 1        services    417
# 2      management    969
# 3     blue-collar    946
# 4   self-employed    183
# 5      technician    768
# 6    entrepreneur    168
# 7          admin.    478
# 8         student     84
# 9       housemaid    112
# 10        retired    230
# 11        unknown     38

# %%
plt.bar('Job', 'Count', data=job_data_df)
plt.title('Job Count Bar Chart')
plt.xlabel('Job')
plt.ylabel('Count')
plt.savefig('Job_Count_Bar_Chart.jpg')
plt.show()

# %%
marital_list = bank_df['marital'].unique()
marital_count_list=[]

for i in bank_df['marital'].unique():
    marital_count_list.append(len(bank_df[bank_df['marital']==i]))

print(marital_list)
print(marital_count_list)
# Out:
# ['married' 'single' 'divorced']
# [2797, 1196, 528]

# %%
data=zip(marital_list,marital_count_list)
cols=['Merit Status','Merit Count']
marital_data_df = pd.DataFrame(data, columns=cols)
print(marital_data_df)
plt.bar('Merit Status','Merit Count',data=marital_data_df)
plt.title('Merit Bar Chart')
plt.xlabel('Merit Status')
plt.ylabel('Merit Count')
plt.savefig('Merit_Bar_Chart.jpg')
plt.show()
# Out:
#   Merit Status  Merit Count
# 0      married         2797
# 1       single         1196
# 2     divorced          528

# %%
import seaborn as sns
order_jobs=bank_df['job'].value_counts().keys()
#print(order_continents)
sns.countplot(data=bank_df,
             x='job',
             order=order_jobs)
plt.title('Job Bar Chart Using Seaborn')
plt.savefig('Job Bar Chart Using Seaborn.jpg')
plt.show()

# %%
order_marital=bank_df['marital'].value_counts().keys()
sns.countplot(data=bank_df,
             x='marital',
             order=order_marital)
plt.title('Bank Marital Bar Chart Using Seaborn')
plt.savefig('Bank_Marital_Bar_Chart_Using_Seaborn.jpg')
plt.show()

# %%
cat_columns = bank_df.value_counts().keys()
cat_columns
# Out:
# MultiIndex([(19,     'student',   'single',   'primary', 'no',  103, ...),
#             (45,    'services',   'single', 'secondary', 'no', 1757, ...),
#             (45,  'technician',  'married', 'secondary', 'no',   88, ...),
#             (45,  'technician',  'married', 'secondary', 'no',   49, ...),
#             (45,  'technician',  'married', 'secondary', 'no', -149, ...),
#             (45,  'technician',  'married',   'primary', 'no', -322, ...),
#             (45,  'technician', 'divorced', 'secondary', 'no',  976, ...),
#             (45,  'technician', 'divorced', 'secondary', 'no',  809, ...),
#             (45,    'services',   'single',   'primary', 'no', 1893, ...),
#             (45,  'technician',  'married', 'secondary', 'no',  118, ...),
#             ...
#             (35, 'blue-collar',  'married', 'secondary', 'no', -339, ...),
#             (35, 'blue-collar',  'married', 'secondary', 'no',  137, ...),
# ...

# %%
types=dict(bank_df.dtypes)
types
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
cat_columns = bank_df.select_dtypes(include='object').columns
cat_columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
import os
dir = 'bank_chart'
current_path = os.getcwd()
bank_path = os.path.join(current_path, dir)
mode = 0o666
os.makedirs(bank_path, mode)
os.getcwd()

# %%
bank_path = os.getcwd() +'\\'+ dir
bank_path
# Out:
# 'C:\\Users\\nagal\\OneDrive\\Documents\\NareshIT\\EDA\\bank_chart'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))  # X-axis:8, Y-axis:5
order_continents=bank_df['marital'].value_counts().keys()
sns.countplot(data=visa_dataset_df, 
                x='continent',
             order=order_continents)
plt.title('Bar chart')
plt.savefig('Continent_bar_chart_using_seaborn.jpg')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
order_continents = bank_df['job'].value_counts().keys()
order_continents

sns.countplot(data=bank_df,x='job',order=order_continents)
plt.title('Bank Job Bar Chart')
plt.savefig(f"{bank_path}\\Bank_Job_Bar_Chart_Using_Seaborn.jpg")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

order_continents = bank_df['job'].value_counts().keys()
plt.figure(figsize=(8,5))
sns.countplot(data=bank_df,
             x='job',
             order=order_continents)
plt.title('Bank Job Chart Using Searborn')
plt.savefig(f"{bank_path}\\bank_job_chart_seaborn.jpg")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def bank_chart(i):
    plt.figure(figsize=(8,5))
    order_continents = bank_df[i].value_counts().keys()
    sns.countplot(data=bank_df,
                 x=i,
                 order=order_continents)
    plt.title(f'Bank {i} Chart Using Seaborn')
    plt.savefig(f"{bank_path}\\{i}_chart_using_seaborn.jpg")
    plt.show()

cat_columns = bank_df.select_dtypes(include='object').columns

for key in cat_columns:
    bank_chart(key)
