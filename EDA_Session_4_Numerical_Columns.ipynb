# %%
***** Import Packages ******

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"C:\Users\nagal\OneDrive\Documents\NareshIT\EDA\Visadataset.csv"
visa_df = pd.read_csv(path)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
****** Convert numerical and Categorical columns ******

# %%
cat_columns = visa_df.select_dtypes(include='object').columns
num_columns = visa_df.select_dtypes(exclude='object').columns
cat_columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'prevailing_wage',
#        'unit_of_wage', 'full_time_position', 'case_status'],
#       dtype='object')

# %%
***** prevailing_wage  ******

# %%
visa_df.loc[:,'prevailing_wage']
visa_df.iloc[:,8]
visa_df['prevailing_wage']
visa_df[['prevailing_wage']]
# Out:
#        prevailing_wage
# 0             592.2029
# 1           83425.6500
# 2          122996.8600
# 3           83434.0300
# 4          149907.3900
# ...                ...
# 25475       77092.5700
# 25476      279174.7900
# 25477      146298.8500
# 25478       86154.7700
# 25479       70876.9100
#
# [25480 rows x 1 columns]

# %%
- len

- min

- max

- average (mean)

- median

- 25p

- 50p

- 75p

# %%
#length
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %%
visa_df.iloc[3:7, 2:5]
# row : 3 4 5 6
# col : 2 3 4
# Out:
#   education_of_employee has_job_experience requires_job_training
# 3            Bachelor's                  N                     N
# 4              Master's                  Y                     N
# 5              Master's                  Y                     N
# 6            Bachelor's                  N                     N

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
count=len(visa_df['prevailing_wage'])
min_wage = min(visa_df['prevailing_wage'])
max_wage = max(visa_df['prevailing_wage'])
print(f'The number of wages are : {count}')
print(f'The minimum wage is : {min_wage}')
print(f'The maximum wage is : {max_wage}')
# Out:
# The number of wages are : 25480
# The minimum wage is : 2.1367
# The maximum wage is : 319210.27

# %%
visa_df[['prevailing_wage']].mean()
# Out:
# prevailing_wage    74455.814592
# dtype: float64

# %%
visa_df['prevailing_wage'].mean()
# Out:
# 74455.81459209183

# %%
mean_wage = round(visa_df['prevailing_wage'].mean(),2)
median_wage = round(visa_df['prevailing_wage'].mean(),2)
print(f'The average of mean_wage is : {min_wage}')
print(f'The average of median_wage is  : {median_wage}')
# Out:
# The average of mean_wage is : 2.1367
# The average of median_wage is  : 74455.81

# %%
- Mode is not suitable metric for numerical analysis
- Different observations can have same values

# %%
# **** Using numpy *****
np.mean(visa_df['prevailing_wage'])
# Out:
# 74455.81459209183

# %%
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %%
#--- Standard Deviation ------------
std_wage = round(visa_df['prevailing_wage'].std(), 2)
print(std_wage)
# Out:
# 52815.94

# %%
count_wage=len(visa_df['prevailing_wage'])
min_wage = min(visa_df['prevailing_wage'])
max_wage = max(visa_df['prevailing_wage'])
mean_wage = round(visa_df['prevailing_wage'].mean(),2)
median_wage = round(visa_df['prevailing_wage'].mean(),2)
std_wage = round(visa_df['prevailing_wage'].std(), 2)
print(f'The number of wages are : {count}')
print(f'The minimum wage is : {min_wage}')
print(f'The maximum wage is : {max_wage}')
# Out:
# The number of wages are : 25480
# The minimum wage is : 2.1367
# The maximum wage is : 319210.27

# %%
#Step-1 : Create a empty list, keep all the values in a list
#Step-2 : Create a index list = ['count', 'min', 'max']
#Step-3 : Create a cols list = ['pwage']

# %%
values =[count_wage, min_wage, max_wage, mean_wage, median_wage, std_wage]
index = ['count', 'min', 'max', 'mean', 'median', 'std']
cols = ['prevailing_wage']
pd.DataFrame(values, index=index, columns=cols)
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       74455.8100
# std          52815.9400

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
****25p-50p-75p****

# %%
*** Percentile ****
 - In numpy we have percentile
 - The method is np.percentile()
    - It takes two arguments
     - a : aray means data
     - q : which percentile data we want, that value we need to provided
     - If we want 25p value then q=25

***** Quantile *****
  - In numpy we have quantile method
  - the method is np.quantile()
  - If we want 25p, the value q=0.25
  - If we want 50p, the value q=0.50
  - Quantile must be in the range of [0, 1]

# %%
wage_25p = np.percentile(visa_df['prevailing_wage'],25)
wage_25p
# Out:
# 34015.479999999996

# %%
np.quantile(visa_df['prevailing_wage'],0.25)
# Out:
# 34015.479999999996

# %%
wage_25p = round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p = round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p = round(np.percentile(visa_df['prevailing_wage'],75),2)
print(f'25p value is : {wage_25p}')
print(f'50p value is : {wage_50p}')
print(f'75p value is : {wage_75p}')
# Out:
# 25p value is : 34015.48
# 50p value is : 70308.21
# 75p value is : 107735.51

# %%
count_wage=len(visa_df['prevailing_wage'])
min_wage = min(visa_df['prevailing_wage'])
max_wage = max(visa_df['prevailing_wage'])
mean_wage = round(visa_df['prevailing_wage'].mean(),2)
median_wage = round(visa_df['prevailing_wage'].mean(),2)
std_wage = round(visa_df['prevailing_wage'].std(), 2)
wage_25p = round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p = round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p = round(np.percentile(visa_df['prevailing_wage'],75),2)
values =[count_wage, min_wage, max_wage, mean_wage, median_wage, std_wage, wage_25p, wage_50p, wage_75p]
index = ['count', 'min', 'max', 'mean', 'median', 'std', '25p', '50p', '75p']
cols = ['prevailing_wage']
wage_df=pd.DataFrame(values, index=index, columns=cols)
wage_df
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       74455.8100
# std          52815.9400
# 25p          34015.4800
# 50p          70308.2100
# 75p         107735.5100

# %%
for i in num_columns:
    print(i)
# Out:
# no_of_employees
# yr_of_estab
# prevailing_wage

# %%
df1=pd.DataFrame()
for i in num_columns:
    count_wage=len(visa_df[i])
    min_wage = min(visa_df[i])
    max_wage = max(visa_df[i])
    mean_wage = round(visa_df[i].mean(),2)
    median_wage = round(visa_df[i].mean(),2)
    std_wage = round(visa_df[i].std(), 2)
    wage_25p = round(np.percentile(visa_df[i],25),2)
    wage_50p = round(np.percentile(visa_df[i],50),2)
    wage_75p = round(np.percentile(visa_df[i],75),2)
    values =[count_wage, min_wage, max_wage, mean_wage, median_wage, std_wage, wage_25p, wage_50p, wage_75p]
    index = ['count', 'min', 'max', 'mean', 'median', 'std', '25p', '50p', '75p']
    cols = [i]
    df2=pd.DataFrame(values, index=index, columns=cols)
    df1=pd.concat([df1, df2], axis=1)

print(df1)
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00       25480.0000
# min              -26.00      1800.00           2.1367
# max           602069.00      2016.00      319210.2700
# mean            5667.04      1979.41       74455.8100
# median          5667.04      1979.41       74455.8100
# std            22877.93        42.37       52815.9400
# 25p             1022.00      1976.00       34015.4800
# 50p             2109.00      1997.00       70308.2100
# 75p             3504.00      2005.00      107735.5100

# %%
******* Percentiles *********
  - 25p:
        -- Assume that value 25p = x

        -- 25percentage of data less than value : x
         -- 25percentage of prevailing_wage value : 34015.4800
                That means 25percentage of people less than 34015.4800
        Total members : 25480
            --25percentage of 25480 = 25 * 25480/100 = 6370
                which means 6370 members are less than salary : 34015.4800
    - 50p:
        50 percentage of prevailing_wage value : 70308.210000

# %%
wage_25p =np.percentile(visa_df['prevailing_wage'],25)

# %%
# Step-1 : Read the prevailing_wage data
# Step-2 : Provide the condition
        # prevailing_wage < percentage value
wage_data = visa_df['prevailing_wage']
wage_25p =np.percentile(visa_df['prevailing_wage'],25)
con=wage_data<wage_25p
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
wage_data = visa_df['prevailing_wage']
wage_50p =np.percentile(visa_df['prevailing_wage'],50)
con=wage_data<wage_50p
len(visa_df[con])
# Out:
# 12740

# %%
wage_data = visa_df['prevailing_wage']
wage_75p =np.percentile(visa_df['prevailing_wage'],75)
con=wage_data<wage_75p
len(visa_df[con])
# Out:
# 19110

# %%
**** Empirical rule:  ********
mean-1std to mean+1std : 68%
mean-2std to mean+2std : 95%
mean-3std to mean+3std : 99.7%

# %%
https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/1_empirical-rule.jpg
# Out:
#   Cell In[19], line 1
#     https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/1_empirical-rule.jpg
#                                                                                                    ^
# SyntaxError: invalid decimal literal

# %%
Step-1 : Calculate the mean of prevailining wage
Step-2 : Calculate std of prevailing wage
Step-3 : lb = mean-1 * std
Step-4 : up = mean+1 * std
Step-5 : con1 = data < ub
Step-6 : con2= data > lb
Step-7 : con3 = con1 and con2
Step-8 : data[con3]
Step-9 : compare with 68% 25480 count

# %%
wage_data = visa_df['prevailing_wage']
mu = visa_df['prevailing_wage'].mean()
sigma = visa_df['prevailing_wage'].std()
lb = mu-sigma
ub = mu + sigma
con1=wage_data<ub
con2=wage_data>lb
con3=con1 & con2
wage_68p=wage_data[con3]
print(wage_68p)
print(68*len(visa_df)/100)
# Out:
# 1         83425.65
# 2        122996.86
# 3         83434.03
# 5         78252.14
# 6         53635.39
#            ...
# 25473     22845.56
# 25474     51104.78
# 25475     77092.57
# 25478     86154.77
# 25479     70876.91
# Name: prevailing_wage, Length: 17171, dtype: float64
# 17326.4

# %%
**************95%********************
Step-1 : Calculate the mean of prevailining wage
Step-2 : Calculate std of prevailing wage
Step-3 : lb = mean-2 * std
Step-4 : up = mean+2 * std
Step-5 : con1 = data < ub
Step-6 : con2= data > lb
Step-7 : con3 = con1 and con2
Step-8 : data[con3]
Step-9 : compare with 95% 25480 count

# %%
wage_data = visa_df['prevailing_wage']
mu = visa_df['prevailing_wage'].mean()
sigma = visa_df['prevailing_wage'].std()
lb = mu-2*sigma
ub = mu+2*sigma
con1=wage_data<ub
con2=wage_data>lb
con3=con1 & con2
wage_95p=wage_data[con3]
print(wage_95p)
print(95*len(visa_df)/100)
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25474     51104.7800
# 25475     77092.5700
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 24582, dtype: float64
# 24206.0

# %%
**************98%********************
Step-1 : Calculate the mean of prevailining wage
Step-2 : Calculate std of prevailing wage
Step-3 : lb = mean-3 * std
Step-4 : up = mean+3 * std
Step-5 : con1 = data < ub
Step-6 : con2= data > lb
Step-7 : con3 = con1 and con2
Step-8 : data[con3]
Step-9 : compare with 93% 25480 count

# %%
wage_data = visa_df['prevailing_wage']
mu = visa_df['prevailing_wage'].mean()
sigma = visa_df['prevailing_wage'].std()
lb = mu-3*sigma
ub = mu+3*sigma
con1=wage_data<ub
con2=wage_data>lb
con3=con1 & con2
wage_98p=wage_data[con3]
print(wage_98p)
print(98*len(visa_df)/100)
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25474     51104.7800
# 25475     77092.5700
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25186, dtype: float64
# 24970.4

# %%
******* Describe function: *********

# %%
*********** Histogram *******************
 - By applying emperical rule we observed slight deviation in the count of data
 - Also, Mean is slightly deviated from Median
 - This gives an indication the data does not follow Normal distribution
 - To understand more we will clearly visualize the data
 - It is Numerical data, so the plot name is Histogram
 - Histogram is a graph between Class intervals and Class Interval frequency
 - The plot is available in matplotlib
 - The method name is hist

# %%
Step-1 : Read the prevailing wage
Step-2 : plt.hist() --> Understand the arguments

# %%
wage_data = visa_df['prevailing_wage']
plt.hist(wage_data, 20)
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %%
- Histogram will return  3 values
  - Interval count array
        - We have 20 intervals, so we have 20 interval counts
  - bins
        - bins means number of intervals
        - we have 20 intervals so we need 21 values
 - Will display how many intervals are available

- For example in the bins array the forst two forms one intervals
  - 2.136 to 15962.543 ---> 3863
        3863 observations available between 2.136 to 15962.543
  - 15962.543, 31922.95 ---> 2175
        2175 observations available between 15962.543 to 31922.95

# %%
wage_data = visa_df['prevailing_wage']
count, bins, x = plt.hist(wage_data, bins=20)
print(count)
print(bins)
print(type(bins))
print(x)
# Out:
# [3863. 2175. 2676. 2828. 2889. 2792. 2485. 2066. 1452.  882.  408.  216.
#   206.  167.  129.  111.   66.   48.   10.   11.]
# [2.13670000e+00 1.59625434e+04 3.19229500e+04 4.78833567e+04
#  6.38437634e+04 7.98041700e+04 9.57645767e+04 1.11724983e+05
#  1.27685390e+05 1.43645797e+05 1.59606203e+05 1.75566610e+05
#  1.91527017e+05 2.07487423e+05 2.23447830e+05 2.39408237e+05
#  2.55368643e+05 2.71329050e+05 2.87289457e+05 3.03249863e+05
#  3.19210270e+05]
# <class 'numpy.ndarray'>
# <BarContainer object of 20 artists>

# %%
Verify below two statements:
 2.136 to 15962.543 ---> 3863
        3863 observations available between 2.136 to 15962.543
  - 15962.543, 31922.95 ---> 2175
        2175 observations available between 15962.543 to 31922.95

# %%
lb = 2.13670000e+00
ub = 1.59625434e+04
con1 = visa_df['prevailing_wage'] >= lb
con2 = visa_df['prevailing_wage'] <= ub
con3 = con1 & con2
print(len(visa_df[con3]))
# Out:
# 3863

# %%
lb = 1.59625434e+04
ub = 3.19229500e+04
con1 = visa_df['prevailing_wage'] >= lb
con2 = visa_df['prevailing_wage'] <= ub
con3 = con1 & con2
print(len(visa_df[con3]))
# Out:
# 2175

# %%
lb = 3.19229500e+04
ub = 4.78833567e+04
con1 = visa_df['prevailing_wage'] >= lb
con2 = visa_df['prevailing_wage'] <= ub
con3 = con1&con2
print(len(visa_df[con3]))
# Out:
# 2676

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\nagal\OneDrive\Documents\NareshIT\EDA\Visadataset.csv"
visa_df = pd.read_csv(path)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
cat_columns = visa_df.select_dtypes(include='object').columns
num_columns = visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
******* Box plot *******
 -- Boxplot is used to identify the outliers
 -- Outlier is an observation having huge positive value or huge negative value
 -- Q1 =  
  -- IQR = Inter Quartile Range = Q3 - Q1
  -- Q3 + 1.5 * IQR  and Q1 - 1.5*IQR

# %%
wage_data = visa_df['prevailing_wage']
plt.boxplot(wage_data, vert=False)
plt.title('Box Plot')
plt.xlabel('Wages')
#plt.ylabel()
plt.show()

# %%
wage_data = visa_df['prevailing_wage']
sns.boxplot(wage_data,bins=20)
plt.title('Box plot using Seaborn')
plt.boxplot(wage_data, vert=False)
plt.xlabel('Box plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 wage_data = visa_df['prevailing_wage']
# ----> 2 sns.boxplot(wage_data,bins=20)
#       3 plt.title('Box plot using Seaborn')
#       4 plt.boxplot(wage_data, vert=False)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2239, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     ax = plt.gca()
#    2237 kwargs.update(dict(whis=whis))
# -> 2239 plotter.plot(ax, kwargs)
#    2240 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:888, in _BoxPlotter.plot(self, ax, boxplot_kws)
#     886 def plot(self, ax, boxplot_kws):
#     887     """Make the plot."""
# --> 888     self.draw_boxplot(ax, boxplot_kws)
#     889     self.annotate_axes(ax)
# ...

# %%
wage_data = visa_df['prevailing_wage']
plt.subplot(1,2,1)
plt.hist(wage_data, bins=20)
plt.xlabel('Histogram')
plt.subplot(1,2,2)
plt.boxplot(wage_data, vert=False)
plt.xlabel('Boxplot')
plt.show()

# %%
*******************Find the outliers data ***********************

Step-1:
    Calculate Q1 = 25p
    Calculate Q2 = 50p
    Calculate Q3 = 75p
Step-2 :
    Calculate IQR = Q3-Q1

Step-3 :
    Calculate LB = Q1-1.5*IQR
    Calculate UB = Q3+1.5*IQR

Step-4:
    con1=wage data < LB
    con2=wage data > UB
    con3 = con1 or-and con2

Step-5:
    data = visa_df[con3]

# %%
Q1=np.percentile(visa_df['prevailing_wage'],25)
Q2=np.percentile(visa_df['prevailing_wage'],50)
Q3=np.percentile(visa_df['prevailing_wage'],75)
IQR=Q3-Q1
LB=Q1-1.5*IQR
UB=Q3+1.5*IQR
con1=visa_df['prevailing_wage']<LB
con2= visa_df['prevailing_wage']>UB
con3=con1 | con2
outliers_data=visa_df['prevailing_wage'][con3]
print(len(outliers_data))
# Bitwise operators are used to compare bits data 
# Bits data ===0 and ===1 , True or False'
##### Non outliers data
con1=visa_df['prevailing_wage']>LB
con2= visa_df['prevailing_wage']<UB
con3=con1 & con2
wage_df = visa_df['prevailing_wage']
non_outliers_df=wage_df[con3]
print(len(non_outliers_df))
#dir(non_outliers_df)
#non_outliers_df['prevailing_wage']
# Out:
# 427
# 25053
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
 ---- We have two data frames
        visa_df --> Entire data --> 25480
        Out liers data =427
        Non outliers data = After removing outliers --> 25053
        Tota data(visa_df) = Outliers + Non outliers --> 25053+427

    1) visa_df
    2) non_outliers_df

    First plot non outliers prevailing wage histogram and boxplot

# %%
non_outliers=non_outliers_df['prevailing_wage']
wage_data=visa_df['prevailing_wage']

plt.figure(figsize=(14,3))
plt.suptitle('Comparison of histogram and boxplot')
plt.subplot(1,2,1).hist(wage_data_non_outliers, bins=20)
plt.xlabel('Histogram')
plt.subplot(1,2,2).boxplot(wage_data_non_outliers, vert=False)
plt.xlabel('boxplot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'prevailing_wage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 non_outliers=non_outliers_df['prevailing_wage']
#       2 wage_data=visa_df['prevailing_wage']
#       4 plt.figure(figsize=(14,3))
#
# ...

# %%
non_outliers=non_outliers_df['prevailing_wage']
wage_data=visa_df['prevailing_wage']

plt.figure(figsize=(14,3))
plt.suptitle('Comparison of histogram and boxplot')
plt.subplot(1,2,1).hist(wage_data_non_outliers, bins=20)
plt.xlabel('Histogram')
plt.subplot(1,2,2).boxplot(wage_data_non_outliers, vert=False)
plt.xlabel('boxplot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'prevailing_wage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 non_outliers=non_outliers_df['prevailing_wage']
#       2 wage_data=visa_df['prevailing_wage']
#       4 plt.figure(figsize=(14,3))
#
# ...

# %%
#### Fill the outliers of wage data with Wage median
### 427 outliers
# 427 outliers with Median values(Wage data median values)
# Again draw the plots

# %%
wage_data_non_outliers=non_outliers_df['prevailing_wage']
wage_data_non_outliers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'prevailing_wage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 wage_data_non_outliers=non_outliers_df['prevailing_wage']
#       2 wage_data_non_outliers
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
# ...

# %%
*** How to deal outliers ****
    -1. We can drop outliers
        -- Dropping outliers is an easy task, but not recomonded
        -- If you drop the outliers, we are dropping the rows
        -- Which means we are dropping other caolumn values aslo
        -- May be some important information we might loose from other column values
        -- But in industry if outlier percentage less than 2% of the total data , we can drop.
          -- The number of outliers in wage is 427
         -- The number of total observations are 25480
        -- The percentage is 1.67 which is less than 2%

    -2. Fill with median value
        -- We already know that outliers does not effect by median
        -- So it is the best practive to fill the outliers with median

    -3. Capping or Florring
        - Instead of fill with mdian
            -we can certain values
            -The outliers which are less than LB fill with LB vlaue
            - The outliers which are greater than UB, fill with UB value
   

    ******Isolation Forest******
    - Is Model used to find the outliers and anamolies

# %% [markdown]
# **** np.where *****
# In numpy we have method called where
#     - It takes three arguments
#         -1. Condition
#         -2. Value if condition is True
#         -3. Value if conditions is False
#
# - It is applicable only Binary means if and else

# %%
list1=[]
for value in wage_data:
    if value < LB or value > UB:
        median=wage_data.median()
        list1.append(median)
    else:
        list1.append(value)

list1
# Out:
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  70308.20999999999,
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  70308.20999999999,
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
#  121316.5,
#  122540.55,
# ...

# %%
dict1={'Sub': ['DS', 'DE', 'CS'],
   'marks': [100, 200, 300]
   }

df=pd.DataFrame(dict1)
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE    200
# 2  CS    300

# %%
# I want to replace marks with 1, which are greater than 100
l=[]
for i in df.marks:
    if i>100:
        l.append(1)
    else:
        l.append(i)

df['New'] = l
print(df)
# Out:
#   Sub  marks  New
# 0  DS    100  100
# 1  DE    200    1
# 2  CS    300    1

# %%
# np.where(<Condition>, <True>, <False>)
con = df['marks']>100
np.where(con, 1, df['marks'])
df['marks']=l
df
# Out:
#   Sub  marks  New
# 0  DS    100  100
# 1  DE      1    1
# 2  CS      1    1

# %%
wage_dat=visa_df['prevailing_wage']
con1=wage_data < LB
con2 = wage_data > UB
con = con1 | con2
wage_med=wage_data.median
l=[]
l=np.where(con, wage_med, wage_data)
l
# Out:
# array([592.2029, 83425.65, 122996.86, ..., 146298.85, 86154.77, 70876.91],
#       dtype=object)

# %%
visa_df['prevailing_wage']=l
visa_df['prevailing_wage']
# Out:
# 0                                                 592.2029
# 1                                                 83425.65
# 2                                                122996.86
# 3                                                 83434.03
# 4                                                149907.39
#                                ...
# 25475                                             77092.57
# 25476    <bound method Series.median of 0           592...
# 25477                                            146298.85
# 25478                                             86154.77
# 25479                                             70876.91
# Name: prevailing_wage, Length: 25480, dtype: object

# %%
plt.subplot1,2,1).boxplot()
